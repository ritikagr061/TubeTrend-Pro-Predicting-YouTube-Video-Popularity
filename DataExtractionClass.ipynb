# %%
from googleapiclient.discovery import build
import pandas as pd
import schedule
import time

#AIzaSyDImhc8-_62z2gQlC9juQuirUeffpzd-4Q      - ritik061
#AIzaSyBDBfa34RY3qj7N_cHhLCHzU7VI6shmi14      -joedog
#AIzaSyCOI7w-Xrw3qX6XBCtd0QtoUC_2XwkQsWU      -8800
#AIzaSyD3UrhmicKhM4SDep3Q8rzdbHVQao7RX8Q     -ritikagr734
#AIzaSyAb5YXxhTRX6Z6-7qP2H6gxXryfdfsZb1A     -jyoti 1
#AIzaSyC8yx1P3vz9evgBV_tt0e0OrjeACA7OymY     -jyoti 2 
#AIzaSyAsWBftPqQjPM49TC8lYHb_sUZJnQx_0QY     -jyoti 3
#AIzaSyCTFyzmViVnpfRD7rjfw_TBCxX3EQ4p8Zc    -sham 1
#AIzaSyBYDvJQKtKjqF4W7BCsp_zQeLG2jE16iUY     -sham 2


channels_dic1={'tvf':'UCNJcSUSzUeFm8W9P7UUlSeQ' , 'tsp':'UCNyeSfUfffmJXwA2_tmNG9A'  , 'timeliners':'UCTlnaHHQ75zlDg_fLr7tGEg' ,
             'girliyappa':'UCdxbhKxr8pyWTx1ExCSmJRw','rvcj':'UCGyEq-EoY4Gn4RfknRQxWYw'}

#channels_dic2={'dhruv rathee':'UC-CSyyi47VX1lD9zyeABW3w' , 'abhi and niyu':'UCsDTy8jvHcwMvSZf_JGi-FA' , 'the deshbhakt':'UCmTM_hPCeckqN3cPWtYZZcg'
#              , 'soch-mangal mohak':'UCz4a7agVFr1TxU-mpAP8hkw'}


channels_dic={'soch-mangal mohak':'UCz4a7agVFr1TxU-mpAP8hkw','girliyappa':'UCdxbhKxr8pyWTx1ExCSmJRw','rvcj':'UCGyEq-EoY4Gn4RfknRQxWYw',
             'tsp':'UCNyeSfUfffmJXwA2_tmNG9A','timeliners':'UCTlnaHHQ75zlDg_fLr7tGEg','abhi and niyu':'UCsDTy8jvHcwMvSZf_JGi-FA',
              'tvf':'UCNJcSUSzUeFm8W9P7UUlSeQ','dhruv rathee':'UC-CSyyi47VX1lD9zyeABW3w','the deshbhakt':'UCmTM_hPCeckqN3cPWtYZZcg'}

#for channel_name,channel_id in channels_dic1.items():

api_key="AIzaSyAb5YXxhTRX6Z6-7qP2H6gxXryfdfsZb1A" #jyoti 3  next you should use 8800 , 734 and then jyoti1 , ritikagr061 , sham2

path_to_base_directory='C:/Users/sudhi/PycharmProjects/minor project-1/CSVs/'
channel_names=['abhi and niyu','dhruv rathee','girliyappa','rvcj','soch-mangal mohak','the deshbhakt','timeliners','tvf','tsp']

# %%
variables=['title', 'description', 'publishedAt', 'duration', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'thumbnails', 'tags']


class Yt_stat_class:

    def __init__(self,api_key,channel_id,channel_name,path_to_channel_csvs):
        self.api_key=api_key
        self.channel_id=channel_id
        self.channel_name=channel_name
        self.video_id_list=[]
        self.base_path=path_to_channel_csvs
        self.all_data={'id':[],'title':[],'description':[],'publishedAt':[],'duration':[],'viewCount':[],'likeCount':[],'dislikeCount':[],'commentCount':[],'thumbnails':[],'tags':[]}
        
        #self.video_id_list  : getting current vedios id list from saved csv file
        df=pd.read_csv(self.base_path+self.channel_name+'/id.csv')
        self.video_id_list=list(df.columns.values)
        self.video_id_list=self.video_id_list[1:]  # removing the unwanted Unammed:0 from the list

        del df
        
        
        
    #2
    def get_channel_new_video_id(self): #this function will extract 10 latest video id list and save it to dictionary response
        
        #https://youtube.googleapis.com/youtube/v3/search?part=snippet%2Cid&channelId=UCNJcSUSzUeFm8W9P7UUlSeQ&maxResults=3&order=date&key=AIzaSyDImhc8-_62z2gQlC9juQuirUeffpzd-4Q
        youtube = build('youtube', 'v3', developerKey=api_key)
    
        request = youtube.search().list(
        part="snippet,id",
        channelId=self.channel_id,
        maxResults=10,
        order="date",
        )

        response = request.execute()  #response is of type dictionary and request is json file

        
        self._get_channel_new_video_id(response)
        # we got a dictionary as a response which contains different vedio details which we will extract using a helper function
        
        
    def _get_channel_new_video_id(self,response):  # helper function , used for checking for new ids
        
        new_ids=[]
        for list in response['items']:
            if(list["id"]['kind']=="youtube#video"):
                if(self.video_id_list[0]==list['id']['videoId']):
                    break
                else:
                    new_ids.append(list['id']['videoId'])
                    
        #new_ids is a list containing ved ids like [ most latest , ... , least latest]
        print(new_ids)
        if new_ids!=[]:
            self.add_new_ids(new_ids)
                    
    def add_new_ids(self,new_ids): #if there are new videos added then these new video ids will get updated in all csvs
        
        #import csv file one by one
        #add new column at the front
        #save and close the csv
        #repeat 
        df=pd.read_csv(self.base_path+self.channel_name+'/'+'id.csv',index_col=0)
        for i in reversed(new_ids):
            print(type(i))
            try:
                df.insert(0,i,[])
            except ValueError:
                    print('ValueError ara')
            
        df.to_csv(self.base_path+self.channel_name+'/'+'id.csv')
        
        for var in variables:
            df=pd.read_csv(self.base_path+self.channel_name+'/'+var+'.csv',index_col=0)
            for i in reversed(new_ids):
                
                    df.insert(1,i,['' for i in range(len(df.index))])
                
            df.to_csv(self.base_path+self.channel_name+'/'+var+'.csv')
        
    def get_video_details(self):
        
        full_id_list=self.video_id_list
        for i in range(0, len(full_id_list), 10):
            
            if(i+10>len(full_id_list)-1):
                k=-1
            else:
                k=i+10
            ids=full_id_list[i:k]
            Id=','.join(ids)
            #print(Id)
            
            #https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=dkvC9dfKup0%2C%20j4yQMJzZK_0&key=AIzaSyBDBfa34RY3qj7N_cHhLCHzU7VI6shmi14    
            youtube = build('youtube', 'v3', developerKey=api_key)
            request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=Id
            )
            response = request.execute()

            self.store_video_data(response)            

        
        


    def store_video_data(self,response):  # used for extracting vedio details
        
        #'id':,'title':,'desc':'publishedtime':,'tags':,'duration':,'viewcount':,'likecount':,'dislikecount':,'commentcount':,'thumbnail':
        for i in range(response["pageInfo"]["totalResults"]):
            self.all_data['id'].append(response['items'][i]['id'])

            try:
                self.all_data['title'].append(response['items'][i]['snippet']['title'])
            except KeyError:
                self.all_data['title'].append("")
            try:
                self.all_data['description'].append(response['items'][i]['snippet']['description'])
            except KeyError:
                self.all_data['description'].append("")
            try:
                self.all_data['publishedAt'].append(response['items'][i]['snippet']['publishedAt'])
            except KeyError:
                self.all_data['publishedAt'].append("")
            try:
                self.all_data['duration'].append(response['items'][i]['contentDetails']['duration'])
            except KeyError:
                self.all_data['duration'].append("")
            try:
                self.all_data['viewCount'].append(response['items'][i]['statistics']['viewCount'])
            except KeyError:
                self.all_data['viewCount'].append("")
            try:
                self.all_data['likeCount'].append(response['items'][i]['statistics']['likeCount'])
            except KeyError:
                self.all_data['likeCount'].append("")
            try:
                self.all_data['dislikeCount'].append(response['items'][i]['statistics']['dislikeCount'])
            except KeyError:
                self.all_data['dislikeCount'].append("")
            try:
                self.all_data['commentCount'].append(response['items'][i]['statistics']['commentCount'])
            except KeyError:
                self.all_data['commentCount'].append("")
            try:
                self.all_data['thumbnails'].append(response['items'][i]['snippet']['thumbnails']['high']['url'])
            except KeyError:
                self.all_data['thumbnails'].append("")


            #storing tags data
            tags_str=""
            try:
                for j in response['items'][i]['snippet']['tags']:
                    tags_str=tags_str+','+j                       # sturcture is ",tag1,tag2,tag3...."
            except KeyError:
                pass
            self.all_data['tags'].append(tags_str)


    def append_to_csvs(self):
        
        #time:getting exact date+time here in IST(indian standar timezone) in the format %d-%m-%Y_%H:%M
        from datetime import datetime
        from pytz import timezone    
        india = timezone('Asia/Kolkata')
        ind_time = datetime.now(india)
        time=ind_time.strftime('%d-%m-%Y_%H:%M')
        
        for var in variables:
            df=pd.read_csv(self.base_path+self.channel_name+'/'+var+'.csv',index_col=0)
            
            last_index=len(df.index)
            #print(last_index)
            df.loc[last_index,'timestamp']=time
            
            X_id=self.all_data['id']
            X_var=self.all_data[var]
        
            for x1,x2 in zip(X_id,X_var):
                
                df.loc[last_index,x1]=x2
            #print(df)  
            print(var+self.channel_name+"------THE NO. OF NAN VALUES ARE ::: " + str(df.isna().sum().sum()))
            df.to_csv(self.base_path+self.channel_name+'/'+var+'.csv')

# %%
def record_data():
    
    t = time.localtime()
    hr = time.strftime("%H", t)
    print(hr)
    
  #  if int(hr)>20 :
       # api_key="AIzaSyCTFyzmViVnpfRD7rjfw_TBCxX3EQ4p8Zc"
   # elif int(hr)< 5:
    #    api_key="AIzaSyCTFyzmViVnpfRD7rjfw_TBCxX3EQ4p8Zc"
   # else :
    #    api_key="AIzaSyAsWBftPqQjPM49TC8lYHb_sUZJnQx_0QY"
        
    print(api_key)
    
    path_to_base_directory='C:/Users/sudhi/PycharmProjects/minor project-1/CSVs/'

    channels_dic={'soch-mangal mohak':'UCz4a7agVFr1TxU-mpAP8hkw','girliyappa':'UCdxbhKxr8pyWTx1ExCSmJRw','rvcj':'UCGyEq-EoY4Gn4RfknRQxWYw',
                 'tsp':'UCNyeSfUfffmJXwA2_tmNG9A','timeliners':'UCTlnaHHQ75zlDg_fLr7tGEg','abhi and niyu':'UCsDTy8jvHcwMvSZf_JGi-FA',
                  'tvf':'UCNJcSUSzUeFm8W9P7UUlSeQ','dhruv rathee':'UC-CSyyi47VX1lD9zyeABW3w','the deshbhakt':'UCmTM_hPCeckqN3cPWtYZZcg'}

    for channel_name,channel_id in channels_dic.items():
        Yt=Yt_stat_class(api_key,channel_id,channel_name,path_to_base_directory)
        Yt.video_id_list
        Yt.get_channel_new_video_id()
        Yt.get_video_details()
        Yt.append_to_csvs()
        


from googleapiclient.discovery import build
import pandas as pd
import schedule
import time



j1=schedule.every().day.at("00:40").do(record_data)
j2=schedule.every().day.at("00:00").do(record_data)
j3=schedule.every().day.at("01:10").do(record_data)
j4=schedule.every().day.at("02:00").do(record_data)
j5=schedule.every().day.at("03:00").do(record_data)
j6=schedule.every().day.at("04:00").do(record_data)
j7=schedule.every().day.at("05:00").do(record_data)



while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# 00
# AIzaSyAb5YXxhTRX6Z6-7qP2H6gxXryfdfsZb1A
# []
# titlesoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# descriptionsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 432
# publishedAtsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# durationsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# viewCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# likeCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# dislikeCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# commentCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# thumbnailssoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# tagssoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# []
# titlegirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# descriptiongirliyappa------THE NO. OF NAN VALUES ARE ::: 994
# publishedAtgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# durationgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# viewCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# likeCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# dislikeCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# commentCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# thumbnailsgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# tagsgirliyappa------THE NO. OF NAN VALUES ARE ::: 3503
# []
# titlervcj------THE NO. OF NAN VALUES ARE ::: 391
# descriptionrvcj------THE NO. OF NAN VALUES ARE ::: 816
# publishedAtrvcj------THE NO. OF NAN VALUES ARE ::: 391
# durationrvcj------THE NO. OF NAN VALUES ARE ::: 391
# viewCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# likeCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# dislikeCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# commentCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# thumbnailsrvcj------THE NO. OF NAN VALUES ARE ::: 391
# tagsrvcj------THE NO. OF NAN VALUES ARE ::: 499
# []
# titletsp------THE NO. OF NAN VALUES ARE ::: 326
# descriptiontsp------THE NO. OF NAN VALUES ARE ::: 326
# publishedAttsp------THE NO. OF NAN VALUES ARE ::: 326
# durationtsp------THE NO. OF NAN VALUES ARE ::: 326
# viewCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# likeCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# dislikeCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# commentCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# thumbnailstsp------THE NO. OF NAN VALUES ARE ::: 326
# tagstsp------THE NO. OF NAN VALUES ARE ::: 1730
# []
# titletimeliners------THE NO. OF NAN VALUES ARE ::: 388
# descriptiontimeliners------THE NO. OF NAN VALUES ARE ::: 405
# publishedAttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# durationtimeliners------THE NO. OF NAN VALUES ARE ::: 388
# viewCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# likeCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# dislikeCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# commentCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# thumbnailstimeliners------THE NO. OF NAN VALUES ARE ::: 388
# tagstimeliners------THE NO. OF NAN VALUES ARE ::: 2997
# []
# titleabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# descriptionabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1133
# publishedAtabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# durationabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# viewCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# likeCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# dislikeCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# commentCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1478
# thumbnailsabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1370
# tagsabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1693
# []
# titletvf------THE NO. OF NAN VALUES ARE ::: 281
# descriptiontvf------THE NO. OF NAN VALUES ARE ::: 527
# publishedAttvf------THE NO. OF NAN VALUES ARE ::: 281
# durationtvf------THE NO. OF NAN VALUES ARE ::: 281
# viewCounttvf------THE NO. OF NAN VALUES ARE ::: 281
# likeCounttvf------THE NO. OF NAN VALUES ARE ::: 389
# dislikeCounttvf------THE NO. OF NAN VALUES ARE ::: 389
# commentCounttvf------THE NO. OF NAN VALUES ARE ::: 497
# thumbnailstvf------THE NO. OF NAN VALUES ARE ::: 281
# tagstvf------THE NO. OF NAN VALUES ARE ::: 311
# []
# titledhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# descriptiondhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# publishedAtdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# durationdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# viewCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# likeCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# dislikeCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# commentCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 890
# thumbnailsdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# tagsdhruv rathee------THE NO. OF NAN VALUES ARE ::: 890
# []
# titlethe deshbhakt------THE NO. OF NAN VALUES ARE ::: 1255
# descriptionthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 1575
# publishedAtthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# durationthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# viewCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# likeCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# dislikeCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# commentCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# thumbnailsthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# tagsthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 1575
# 00
# AIzaSyAb5YXxhTRX6Z6-7qP2H6gxXryfdfsZb1A
# []
# titlesoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# descriptionsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 432
# publishedAtsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# durationsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# viewCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# likeCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# dislikeCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# commentCountsoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# thumbnailssoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# tagssoch-mangal mohak------THE NO. OF NAN VALUES ARE ::: 266
# []
# titlegirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# descriptiongirliyappa------THE NO. OF NAN VALUES ARE ::: 994
# publishedAtgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# durationgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# viewCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# likeCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# dislikeCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# commentCountgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# thumbnailsgirliyappa------THE NO. OF NAN VALUES ARE ::: 382
# tagsgirliyappa------THE NO. OF NAN VALUES ARE ::: 3503
# []
# titlervcj------THE NO. OF NAN VALUES ARE ::: 391
# descriptionrvcj------THE NO. OF NAN VALUES ARE ::: 816
# publishedAtrvcj------THE NO. OF NAN VALUES ARE ::: 391
# durationrvcj------THE NO. OF NAN VALUES ARE ::: 391
# viewCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# likeCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# dislikeCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# commentCountrvcj------THE NO. OF NAN VALUES ARE ::: 391
# thumbnailsrvcj------THE NO. OF NAN VALUES ARE ::: 391
# tagsrvcj------THE NO. OF NAN VALUES ARE ::: 499
# []
# titletsp------THE NO. OF NAN VALUES ARE ::: 326
# descriptiontsp------THE NO. OF NAN VALUES ARE ::: 326
# publishedAttsp------THE NO. OF NAN VALUES ARE ::: 326
# durationtsp------THE NO. OF NAN VALUES ARE ::: 326
# viewCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# likeCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# dislikeCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# commentCounttsp------THE NO. OF NAN VALUES ARE ::: 326
# thumbnailstsp------THE NO. OF NAN VALUES ARE ::: 326
# tagstsp------THE NO. OF NAN VALUES ARE ::: 1730
# []
# titletimeliners------THE NO. OF NAN VALUES ARE ::: 388
# descriptiontimeliners------THE NO. OF NAN VALUES ARE ::: 405
# publishedAttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# durationtimeliners------THE NO. OF NAN VALUES ARE ::: 388
# viewCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# likeCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# dislikeCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# commentCounttimeliners------THE NO. OF NAN VALUES ARE ::: 388
# thumbnailstimeliners------THE NO. OF NAN VALUES ARE ::: 388
# tagstimeliners------THE NO. OF NAN VALUES ARE ::: 2997
# []
# titleabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# descriptionabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1133
# publishedAtabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# durationabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# viewCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# likeCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# dislikeCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 825
# commentCountabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1478
# thumbnailsabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1370
# tagsabhi and niyu------THE NO. OF NAN VALUES ARE ::: 1693
# []
# titletvf------THE NO. OF NAN VALUES ARE ::: 281
# descriptiontvf------THE NO. OF NAN VALUES ARE ::: 527
# publishedAttvf------THE NO. OF NAN VALUES ARE ::: 281
# durationtvf------THE NO. OF NAN VALUES ARE ::: 281
# viewCounttvf------THE NO. OF NAN VALUES ARE ::: 281
# likeCounttvf------THE NO. OF NAN VALUES ARE ::: 389
# dislikeCounttvf------THE NO. OF NAN VALUES ARE ::: 389
# commentCounttvf------THE NO. OF NAN VALUES ARE ::: 497
# thumbnailstvf------THE NO. OF NAN VALUES ARE ::: 281
# tagstvf------THE NO. OF NAN VALUES ARE ::: 311
# []
# titledhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# descriptiondhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# publishedAtdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# durationdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# viewCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# likeCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# dislikeCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# commentCountdhruv rathee------THE NO. OF NAN VALUES ARE ::: 890
# thumbnailsdhruv rathee------THE NO. OF NAN VALUES ARE ::: 782
# tagsdhruv rathee------THE NO. OF NAN VALUES ARE ::: 890
# []
# titlethe deshbhakt------THE NO. OF NAN VALUES ARE ::: 1255
# descriptionthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 1575
# publishedAtthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# durationthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# viewCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# likeCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# dislikeCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# commentCountthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# thumbnailsthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 819
# tagsthe deshbhakt------THE NO. OF NAN VALUES ARE ::: 1575
# 00
# AIzaSyAb5YXxhTRX6Z6-7qP2H6gxXryfdfsZb1A
# []

# %%
#schedule.clear()
#schedule.get_jobs()
